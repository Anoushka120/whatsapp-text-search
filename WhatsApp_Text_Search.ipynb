# %%
import os
import cv2
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
image_folder = "images"
text_data = {}
for filename in os.listdir(image_folder):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        img_path = os.path.join(image_folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            extracted_text = pytesseract.image_to_string(img_rgb)
            text_data[filename] = extracted_text.strip()
            print(f"Extracted from: {filename}")
        else:
            print(f" Failed to load: {filename}")
# Out:
# Extracted from: img1.png.png
# Extracted from: img2.png.png

# %%
def search_images(keyword):
    found = False
    for img_name, content in text_data.items():
        if keyword.lower() in content.lower():
            found = True
            print(f"\n Match found in: {img_name}")
            print("-" * 50)
            print(content)
            img_path = os.path.join(image_folder, img_name)
            img = Image.open(img_path)
            plt.imshow(img)
            plt.axis('off')
            plt.show()
    if not found:
        print(" Not found.")

# %%
search_images("")
# Out:
#  Match found in: img1.png.png
# --------------------------------------------------
# : STATS
# Melee Lv. 151
# Defense Lv. 181
# Sword Lv. 127
# Gun Lv. 5
# Blox Fruit Lv. 132
# Available Points: 0

# %%
#import os
#print(os.getcwd())
